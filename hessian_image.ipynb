# %%
import cv2
import matplotlib.pyplot as plt
from skimage.feature import hessian_matrix, hessian_matrix_eigvals

# %%
IMG_PATH = "Images/h_pipes_Big.jpg"
img = cv2.imread(IMG_PATH, cv2.IMREAD_UNCHANGED)
plt.imshow(img)
plt.show()

# %%
Hessen = hessian_matrix(img, sigma=1.5)
eigen1, eigen2 = hessian_matrix_eigvals(Hessen[0], Hessen[1], Hessen[2])
# Out:
# /home/anirudh/.local/lib/python3.5/site-packages/skimage/feature/corner.py:338: UserWarning: The API of `hessian_matrix_eigvals` has changed. Use a list of elements instead of separate arguments. The old version of the API will be removed in version 0.16.
#   warn('The API of `hessian_matrix_eigvals` has changed. Use a list of '

# %%
# eigen1, eigen2 = hessian_matrix_eigvals(H_elems=Hessen)

# %%
plt.imshow(eigen2)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(eigen2)
plt.show()
